# %% [markdown]
# Script to merge the outputs of all the tools into one big table also get consensus substructures (on motif basis) for insilico-tools and propagate canopus within networks + ms2lda

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
from rdkit.Chem import MCS
from rdkit.Chem import MolFromSmarts
from collections import Counter
from rdkit.Chem.Fraggle import FraggleSim
from rdkit.Chem.rdMolDescriptors import CalcNumAtoms
from rdkit.Chem import rdMolDescriptors
from rdkit.SimDivFilters import rdSimDivPickers
from rdkit import DataStructs
from collections import defaultdict
import numpy as np
from matplotlib.pyplot import hist,xlabel
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.rdBase import BlockLogs
from tqdm.notebook import tqdm

def convert(molecule): #repair InChI and convert to smiles
    try:
        if not molecule.startswith("InChI="):
            molecule="InChI="+molecule
        else:
            pass
        mol=Chem.inchi.MolFromInchi(molecule)
        return(Chem.MolToSmiles(mol,kekuleSmiles=True))
    except:
        return None
    
def smilestomf(smiles):
    try:
        m = Chem.MolFromSmiles(smiles)
        u=CalcMolFormula(m)
        return u
    except:
        return None    
    






def assignPointsToClusters(picks,fps):
    clusters = defaultdict(list)
    for i,idx in enumerate(picks):
        clusters[i].append(idx)
    sims = np.zeros((len(picks),len(fps)))
    for i in range(len(picks)):
        pick = picks[i]
        sims[i,:] = DataStructs.BulkTanimotoSimilarity(fps[pick],fps)
        sims[i,i] = 0
    best = np.argmax(sims,axis=0)
    for i,idx in enumerate(best):
        if i not in picks:
            clusters[idx].append(i)
    return clusters
    
def mls(df,columns,thresh = 0.65): # this is the function to calculate the consensus substructure, takes a dataframe, and the columns to select as input
 smiles=[]
 for i in columns:
     smiles=smiles+df[i].dropna().to_list() 
 if len(smiles)>4:   
  y= [Chem.MolFromSmiles(i) for i in smiles]
  scaffolds=[FraggleSim.generate_fraggle_fragmentation(i) for i in y]
  clean=[]
  block = BlockLogs()
  for i in scaffolds:
      newlist = [word for line in i for word in line.split('.')]
      newlist=list(set(newlist))
      newlist = [w.replace('*', '') for w in newlist]
      mfs=[Chem.MolFromSmiles(i) for i in newlist ]
      clean.append(mfs)
  del block
  clean=[j for i in clean for j in i]
  clean=[i for i in clean if not i == None]
  clean=[Chem.MolToSmiles(i) for i in clean]

  most=Counter(clean).most_common()
  most= [i[0] for i in most]
  if len(most)>50:
      most=most[0:50]
  else:
      pass
  mols = [Chem.MolFromSmiles(smi) for smi in most]
  mols = [i for i in mols if CalcNumAtoms(i) >12]

  fps = [rdMolDescriptors.GetMorganFingerprintAsBitVect(m,2,2048) for m in mols]

  lp = rdSimDivPickers.LeaderPicker()
  picks = lp.LazyBitVectorPick(fps,len(fps),thresh)
  clusters = assignPointsToClusters(picks,fps)
  sort_clusters= sorted([clusters[i] for i in clusters],key=len, reverse=True)

  mls=[]
  for _,i in enumerate(range(len(sort_clusters))):
      y=[mols[x] for x in sort_clusters[i]]
      if len(y)>1:
          mls.append(Chem.MolToSmiles(MolFromSmarts(MCS.FindMCS(y,timeout=120).smarts)))
      else:
         pass
  return mls
 else:
        return []
    
columns=["smiles_cfm_db_spec2vec","smiles-sir","smiles_cfm_j","smiles_moldis_j","smiles_moldis","smiles_cfm_db_cosine"]   
    
df_quant = pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/alltissues15072021-quant-py-dil.csv",index_col='row ID', sep=",") # mzmine quant table

df_motif = pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/MS2LDA-all.csv",index_col='row ID', sep=",") # MS2LDA download

df_frag=pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/MS2LDA-fragments.csv",index_col='Motif', sep=",") # MS2LDA download

df_network=pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/allcyto.csv",index_col='shared name', sep=",") # curated gnps output exported from cytoscape

df_sirius=pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/formula_identifications-extended.tsv",index_col='ID', sep="\t") # Sirius output

df_cmpid= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/compound_identifications-extended.tsv",index_col='ID', sep="\t") # Sirius output

df_anno=pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/MS2LDA-annotation.csv",index_col='Name', sep=",") # MS2LDA download

df_moldis= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/MOLDISCOVERY-5561c3b7-view_significant_unique-main.tsv",index_col='Scan', sep="\t") # moldiscovery gnps download

df_moldis_j= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/MOLDISCOVERY-jassbi.tsv",index_col='Scan', sep="\t") # moldiscovery gnps download

df_cfm_j= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/jassbi-results.tsv",index_col='Feature_id', sep="\t") # CFM Datase search output

df_cfm_spec2vec= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/cfm-hits-database_spec2vec.txt",index_col='Feature_id', sep="\t") # CFM Datase search output

df_cfm_cosine= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/results_cfmdb_alltissues1507.tsv",index_col='Feature_id', sep="\t")

df_em= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/hitsemmanuelfilter.tsv",index_col='Feature_id', sep="\t") # Emmanuel Datase search output

df_cano= pd.read_csv("/Users/delser/Desktop/PhD/Phytochemistry/FBMN/alltissues/FEATURE-BASED-MOLECULAR-NETWORKING-cf822b6c-15072021/canopus_summary.tsv", sep="\t")  #canopus data

#df_molnet= pd.read_csv("/Users/delser/Git/phd/molnet_v1.tsv",index_col='cluster index', sep="\t") # molnetenhancher output
# Out:
# <ipython-input-1-d5cc20beeeb1>:5: DeprecationWarning: The rdkit.Chem.MCS module is deprecated; please use rdkit.Chem.rdFMCS instead.
#   from rdkit.Chem import MCS
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/io/parsers.py:2037: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = self._reader.read(nrows)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# get database hits from emmanuel

# %%
df_anno
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                           Degree  \
# Name
# motif_495                   2231
# motif_472                   1684
# motif_489                    987
# motif_664                    965
# motif_595                    917
# ...                          ...
# urine_mass2motif_261.m2m       0
# rhabdus_motif_90.m2m           0
# urine_mass2motif_181.m2m       0
# urine_mass2motif_50.m2m        0
# urine_mass2motif_278.m2m       0
#
#                                                                  Annotation
# Name
# motif_495                                                              None
# motif_472                                                              None
# motif_489                                                              None
# motif_664                                                              None
# motif_595                                                              None
# ...                                                                     ...
# urine_mass2motif_261.m2m  Dechloronated substructure of Chlorphenamine r...
# rhabdus_motif_90.m2m          Xenoamicin related Mass2Motif - peptidic tail
# urine_mass2motif_181.m2m                   Methyladenine related Mass2Motif
# urine_mass2motif_50.m2m   Unclear what it can be - 80.9479 fragment of a...
# urine_mass2motif_278.m2m               Dimethylated guanidino group related
#
# [689 rows x 2 columns]

# %%
df= df_cano['name'].str.split('_',expand=True)
#df.head()
df_cano=df_cano.drop(['name','molecularFormula','adduct'], axis=1)
df_cano=df_cano.join(pd.to_numeric(df[2]))
df_cano=df_cano.rename(columns={'most specific class':"cano_most_specific_class","level 5":"cano_level_5","subclass":"cano_subclass","class":"cano_class","superclass":"cano_superclass","all classifications":"cano_all_classifications",2:"Feature_id"})
df_cano=df_cano.set_index("Feature_id")
#f_cano=df_cano.to_frame()
df_cano.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/internals/construction.py:587: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if dtype != object and dtype != np.object:
#                cano_most_specific_class                 cano_level_5  \
# Feature_id
# 29699           Glycosyldiacylglycerols     Glycosyldiradylglycerols
# 56096       Amino acids and derivatives  Amino acids and derivatives
# 34752              Polyethylene glycols               Dialkyl ethers
# 34264                           Indoles                          NaN
# 26290                Carbonyl compounds                          NaN
#
#                                    cano_subclass  \
# Feature_id
# 29699                          Glycosylglycerols
# 56096       Amino acids, peptides, and analogues
# 34752                                     Ethers
# 34264                                    Indoles
# 26290                         Carbonyl compounds
#
#                                   cano_class                  cano_superclass  \
# Feature_id
# 29699                          Glycerolipids  Lipids and lipid-like molecules
# 56096       Carboxylic acids and derivatives    Organic acids and derivatives
# 34752                 Organooxygen compounds         Organic oxygen compounds
# 34264                Indoles and derivatives     Organoheterocyclic compounds
# 26290                 Organooxygen compounds         Organic oxygen compounds
#
#                                      cano_all_classifications
# Feature_id
# 29699       Organic compounds; Organoheterocyclic compound...
# 56096       Organic compounds; Organoheterocyclic compound...
# 34752       Organic compounds; Alcohols and polyols; Ether...
# 34264       Organic compounds; Organoheterocyclic compound...
# 26290       Organic compounds; Organooxygen compounds; Car...

# %%
df_em=df_em.drop(["m/z","m/z-1","cousine-score-Hit-1","numoffpeaks-1"], axis=1)
df_em=df_em.rename(columns={'Smiles-1':"Smiles","Library-Hit-1":"Compound_Name"})
#df_em=df_em['Level'] = 'N'

df_em.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                                                 Compound_Name  \
# Feature_id
# 43355       N,N`-(4-Azaoctane-1,8-diyl)bis(3-methoxy-4-hyd...
# 43349       N,N`-(4-Azaoctane-1,8-diyl)bis(3-methoxy-4-hyd...
# 46861       N,N`-(4-Azaoctane-1,8-diyl)bis(3-methoxy-4-hyd...
# 43345       N,N`-(4-Azaoctane-1,8-diyl)bis(3-methoxy-4-hyd...
# 43343       N,N`-(4-Azaoctane-1,8-diyl)bis(3-methoxy-4-hyd...
#
#                                                        Smiles
# Feature_id
# 43355       COc1cc(/C=C/C(O)=NCCCCNCCCN=C(O)/C=C/c2ccc(O)c...
# 43349       COc1cc(/C=C/C(O)=NCCCCNCCCN=C(O)/C=C/c2ccc(O)c...
# 46861       COc1cc(/C=C/C(O)=NCCCCNCCCN=C(O)/C=C/c2ccc(O)c...
# 43345       COc1cc(/C=C/C(O)=NCCCCNCCCN=C(O)/C=C/c2ccc(O)c...
# 43343       COc1cc(/C=C/C(O)=NCCCCNCCCN=C(O)/C=C/c2ccc(O)c...

# %% [markdown]
# Pick the hits of the jassbi cfm cousine score search if above 0.5 and min 5 peaks, then get their smiles and extract the sum formulas

# %%
df_cfm_j=df_cfm_j[['m/z',"Library-Hit-1","m/z-1","cousine-score-Hit-1","numoffpeaks-1","Smiles-1"]]

df_cfm_j=df_cfm_j.rename(columns={"cousine-score-Hit-1": "cosine_cfm_j",'Smiles-1':"smiles_cfm_j","Library-Hit-1":"Library-Hit-CFM-jassbi","numoffpeaks-1" :"numoffpeaks__cfm_j"})

df_cfm_j = df_cfm_j[(df_cfm_j.cosine_cfm_j > 0.5) & (df_cfm_j.numoffpeaks__cfm_j > 5)]

"""
sm=df_cfm_j[("smiles_cfm_j")]
l=sm.tolist()

from rdkit import Chem
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
def smilestomf(smiles):
    m = Chem.MolFromSmiles(smiles)
    u=CalcMolFormula(m)
    return u

MF=[]
for i in l:
    MF.append(smilestomf(i))
"""
df_cfm_j["MF_j_cfm"]=df_cfm_j["smiles_cfm_j"].apply(lambda x: smilestomf(x))
#df_cfm_j= df_cfm_j.assign(MF_j_cfm=MF)
#df_cfm_j=df_cfm_j.rename(columns={"MF_j_cfm": "Compound_Name"})
df_cfm_j= df_cfm_j.assign(delta_mz_j_cfm=df_cfm_j["m/z"]-df_cfm_j["m/z-1"])
df_cfm_j
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                  m/z               Library-Hit-CFM-jassbi       m/z-1  \
# Feature_id
# 860         228.1959                        neophytadiene  278.297351
# 930         226.1803                     farnesyl_acetone  262.229666
# 1093        209.1538                             cupalene  202.172151
# 1255        226.1804                     farnesyl_acetone  262.229666
# 1447        209.1537                             cupalene  202.172151
# ...              ...                                  ...         ...
# 56817       367.1754               N-E-caffeoyl_tyramine_  299.115758
# 57105       203.1795                     farnesyl_acetone  262.229666
# 57152       404.2644                      occidol_acetate  260.177630
# 57239       203.1794                     farnesyl_acetone  262.229666
# 57397       404.2643  2,4-diphenyl-4-methyl-2-(Z)-pentene  236.156501
#
#             cosine_cfm_j  numoffpeaks__cfm_j  \
# Feature_id
# 860             0.511559                   7
# 930             0.561156                  18
# 1093            0.532549                   9
# 1255            0.570614                  11
# 1447            0.538105                   9
# ...                  ...                 ...
# 56817           0.540279                  12
# 57105           0.539936                  11
# 57152           0.505505                  10
# 57239           0.525324                  12
# 57397           0.507531                   8
#
#                                       smiles_cfm_j   MF_j_cfm  delta_mz_j_cfm
# Feature_id
# 860                 C=CC(=C)CCCC(C)CCCC(C)CCCC(C)C     C20H38      -50.101451
# 930            CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C    C18H30O      -36.049366
# 1093                     Cc1ccc(C2(C)CCCC2(C)C)cc1     C15H22        6.981649
# 1255           CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C    C18H30O      -36.049266
# 1447                     Cc1ccc(C2(C)CCCC2(C)C)cc1     C15H22        6.981549
# ...                                            ...        ...             ...
# 56817       OC(/C=C/c1ccc(O)c(O)c1)=NCCc1ccc(O)cc1  C17H17NO4       68.059642
# 57105          CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C    C18H30O      -59.050166
# 57152           CC(=O)OC(C)(C)C1CCc2c(C)ccc(C)c2C1   C17H24O2      144.086770
# 57239          CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C    C18H30O      -59.050266
# 57397              C/C(=C/C(C)(C)c1ccccc1)c1ccccc1     C18H20      168.107799
#
# [999 rows x 8 columns]

# %%
df_cfm_j=df_cfm_j.drop(["m/z","m/z-1"], axis=1)
df_cfm_j
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                          Library-Hit-CFM-jassbi  cosine_cfm_j  \
# Feature_id
# 860                               neophytadiene      0.511559
# 930                            farnesyl_acetone      0.561156
# 1093                                   cupalene      0.532549
# 1255                           farnesyl_acetone      0.570614
# 1447                                   cupalene      0.538105
# ...                                         ...           ...
# 56817                    N-E-caffeoyl_tyramine_      0.540279
# 57105                          farnesyl_acetone      0.539936
# 57152                           occidol_acetate      0.505505
# 57239                          farnesyl_acetone      0.525324
# 57397       2,4-diphenyl-4-methyl-2-(Z)-pentene      0.507531
#
#             numoffpeaks__cfm_j                            smiles_cfm_j  \
# Feature_id
# 860                          7          C=CC(=C)CCCC(C)CCCC(C)CCCC(C)C
# 930                         18     CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C
# 1093                         9               Cc1ccc(C2(C)CCCC2(C)C)cc1
# 1255                        11     CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C
# 1447                         9               Cc1ccc(C2(C)CCCC2(C)C)cc1
# ...                        ...                                     ...
# 56817                       12  OC(/C=C/c1ccc(O)c(O)c1)=NCCc1ccc(O)cc1
# 57105                       11     CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C
# 57152                       10      CC(=O)OC(C)(C)C1CCc2c(C)ccc(C)c2C1
# 57239                       12     CC(=O)CC/C=C(\C)CC/C=C(\C)CCC=C(C)C
# 57397                        8         C/C(=C/C(C)(C)c1ccccc1)c1ccccc1
#
#              MF_j_cfm  delta_mz_j_cfm
# Feature_id
# 860            C20H38      -50.101451
# 930           C18H30O      -36.049366
# 1093           C15H22        6.981649
# 1255          C18H30O      -36.049266
# 1447           C15H22        6.981549
# ...               ...             ...
# 56817       C17H17NO4       68.059642
# 57105         C18H30O      -59.050166
# 57152        C17H24O2      144.086770
# 57239         C18H30O      -59.050266
# 57397          C18H20      168.107799
#
# [999 rows x 6 columns]

# %%
df_moldis.head()
df_moldis=df_moldis.drop(["SpecFile","LocalSpecIdx","LocalPeptideIdx","Retention","SpectrumMass","PeptideMass","Score","FDR"], axis=1)

df_moldis=df_moldis.rename(columns={"MassDiff": "delta_mz_moldis", "Name": "Hit_moldis", "SMILES": "smiles_moldis","Adduct": "MoldisAdduct","Charge": "Charge_moldis"})

df_moldis.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                                           Hit_moldis  delta_mz_moldis  \
# Scan
# 29090                                            NaN         -0.00062
# 31432                           Lyciumins_Lyciumin_C         -0.00182
# 31922  7,7',8,8',11,12-Hexahydrolycopene_1,2-Epoxide         -0.00032
# 7753        15,7',8',11',12',15'-Hexahydro-beta,psi-         -0.00002
# 7763                           Polyprenol_Octaprenol         -0.00032
#
#       MoldisAdduct  Charge_moldis  \
# Scan
# 29090          M+H              1
# 31432          M+H              1
# 31922          M+H              1
# 7753           M+H              1
# 7763           M+H              1
#
#                                            smiles_moldis
# Scan
# 29090  CC(C)[C@@H]1NC(=O)[C@H](Nn2cc(C[C@H](C=O)NC(=O...
# 31432  CC(C)C1NC(=O)C(NC(=O)C(Cc2ccc(O)cc2)NC(=O)C2CC...
# 31922  CC(C)=CCC/C(C)=C\CC/C(C)=C\CC/C(C)=C\C=C\C=C(C...
# 7753   CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C=C(C)...
# 7763   CC(C)=CCC/C(C)=C\CC/C(C)=C\CC/C(C)=C\CC/C(C)=C...

# %%
df_moldis_j.head()
df_moldis_j=df_moldis_j.drop(["SpecFile","LocalSpecIdx","LocalPeptideIdx","Retention","SpectrumMass","PeptideMass","Score","FDR"], axis=1)

df_moldis_j=df_moldis_j.rename(columns={"MassDiff": "delta_mz_moldis_j", "Name": "Hit_moldis_j", "SMILES": "smiles_moldis_j","Adduct": "MoldisAdduct_j","Charge": "Charge_moldis_j"})

df_moldis_j.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                                             Hit_moldis_j  delta_mz_moldis_j  \
# Scan
# 43411                                  nicotianoside_VII           -0.00222
# 36878                                9/9_-cis-neoxanthin            0.00178
# 35284  3-O-alpha-L-rhamnopyranosyl_(1-4)-beta-D-gluco...           -0.00132
# 49796                                   nicotianoside_VI           -0.00102
# 41297                                    nicotianoside_V           -0.00262
#
#       MoldisAdduct_j  Charge_moldis_j  \
# Scan
# 43411            M+H                1
# 36878            M+H                1
# 35284            M+H                1
# 49796            M+H                1
# 41297            M+H                1
#
#                                          smiles_moldis_j
# Scan
# 43411  C=C[C@](C)(CC/C=C(\C)CC/C=C(\C)CC/C=C(/C)CO[C@...
# 36878  CC(=C/C=C/C(C)=C/C=C/C=C(C)/C=C/C=C(\C)C=C=C1C...
# 35284  C=C[C@](C)(CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CO[C@...
# 49796  C=C[C@](C)(CC/C=C(/C)CC/C=C(/C)CC/C=C(\C)CO[C@...
# 41297  C=C[C@](C)(CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CO[C@...

# %% [markdown]
# Pick sirius compound annotations and keep only the ones with confidence above 0.65

# %%
df_cmpid.head()

df_cmpid=df_cmpid.drop(["rank","formulaRank","#adducts","#predictedFPs","CSI:FingerIDScore","ZodiacScore","SiriusScore","molecularFormula","adduct","InChIkey2D","xlogp","dbflags","ionMass","retentionTimeInSeconds","id","pubchemids","links","InChI"], axis=1)
df_cmpid = df_cmpid[(df_cmpid.ConfidenceScore > 0.65) ]
df_cmpid=df_cmpid.rename(columns={ "name": "name-sir", "smiles": "smiles-sir"})

df_cmpid.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#        ConfidenceScore                                           name-sir  \
# ID
# 51061         0.999992                                     Pentapeptide-4
# 33119         0.999957  (4S)-4-[[(2S)-5-(diaminomethylideneamino)-2-[[...
# 20057         0.999955                                                NaN
# 49422         0.999804                                                NaN
# 14394         0.999629                                                NaN
#
#                                               smiles-sir
# ID
# 51061  CC(C(C(=O)NC(C(C)O)C(=O)NC(CCCCN)C(=O)NC(CO)C(...
# 33119  C1=CC=C(C=C1)CC(C(C(=O)NC(CCCN=C(N)N)C(=O)NC(C...
# 20057  CC1=CN(C(=O)NC1=O)C2CC(C(O2)CNC(=O)CCCCCCCC(=O...
# 49422  CC(C)CC(C(=O)NC(C)(C)C(=O)NC(CC(C)C)C(=O)NC(C)...
# 14394  CC(C)CC(=O)OC1C2C(CCC2C(=CO1)COC3C(C(C(C(O3)CO...

# %% [markdown]
# df_frag.head()

# %%
df_sirius.head()
#df_motif_red=df_motif.drop(["Precursor Mass","Retention Time","Document Annotation","Document","Probability","Overlap Score"], axis=1)
df_sirius=df_sirius.drop(["rank","ZodiacScore","SiriusScore","TreeScore","IsotopeScore","numExplainedPeaks","explainedIntensity","medianMassErrorFragmentPeaks(ppm)","medianAbsoluteMassErrorFragmentPeaks(ppm)","massErrorPrecursor(ppm)","ionMass","retentionTimeInSeconds"], axis=1)
#df_motif_red.head()

df_sirius.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#       molecularFormula    adduct precursorFormula  \
# ID
# 29312         C29H46O2  [M + H]+         C29H46O2
# 29190         C28H46O2  [M + H]+         C28H46O2
# 29298         C29H48O2  [M + H]+         C29H48O2
# 29188         C28H44O2  [M + H]+         C28H44O2
# 50689         C20H32O3  [M + H]+         C20H32O3
#
#                                             id  degree
# ID
# 29312   6422_altissues15072021-sirius-py_29312     7.0
# 29190   6350_altissues15072021-sirius-py_29190     6.0
# 29298   6417_altissues15072021-sirius-py_29298     6.0
# 29188   6349_altissues15072021-sirius-py_29188     7.0
# 50689  14102_altissues15072021-sirius-py_50689     5.0

# %% [markdown]
# Get CFM big DB search by spec2vec, keep only ic score above 0.5

# %%
df_cfm_spec2vec=df_cfm_spec2vec.drop(["hit2","hit2_m/z","hit2_score","hit3","hit3_m/z","hit3_score","hit4","hit4_m/z","hit4_score","hit5","hit5_m/z","hit5_score","hit6","hit6_m/z","hit6_score"], axis=1)
df_cfm_spec2vec=df_cfm_spec2vec.rename(columns={"hit1": "cfm_db_spec2vec_hit",'hit1_SMILES':"smiles_cfm_db_spec2vec","hit1_MolecularFormula":"MolecularFormula_cfm_db_spec2vec","hit1_score" :"score_cfm_db_spec2vec"})
df_cfm_spec2vec = df_cfm_spec2vec[(df_cfm_spec2vec.score_cfm_db_spec2vec > 0.5)]
df_cfm_spec2vec = df_cfm_spec2vec .assign(delta_cfm_spec2vec=df_cfm_spec2vec ["m/z"]-df_cfm_spec2vec ["hit1_m/z"])
#df_cfm_spec2vec = df_cfm_spec2vecj[(df_cfm_j.cosine_cfm_j > 0.5) & (df_cfm_j.numoffpeaks__cfm_j > 5)]
df_cfm_spec2vec
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                  m/z cfm_db_spec2vec_hit          smiles_cfm_db_spec2vec  \
# Feature_id
# 38          526.4316               62551              C(COCCOCCOCCOCCO)O
# 40          570.4579               62551              C(COCCOCCOCCOCCO)O
# 45          540.4472               62551              C(COCCOCCOCCOCCO)O
# 48          526.4316               62551              C(COCCOCCOCCOCCO)O
# 49          614.4842               62551              C(COCCOCCOCCOCCO)O
# ...              ...                 ...                             ...
# 56292       579.4995             5312697        CCCC#CCCCCCCCCCCCCC(=O)O
# 57074       404.2640          PMA_119625      CC1=C2CCCC[C@@]2(C)C=CC1=O
# 57076       420.2593          PMA_054517  CC1=CCC(CC1=O)C(=C)CCCC(C)(C)O
# 57177       413.3779          CNP0287127      C=C1C2CCC32CC(CCC13C)C(C)C
# 57397       404.2643          PMA_210145     Cc1coc2CC3(C)CCCC(=C)C3Cc12
#
#            MolecularFormula_cfm_db_spec2vec    hit1_m/z  \
# Feature_id
# 38                                 C10H22O6  238.141638
# 40                                 C10H22O6  238.141638
# 45                                 C10H22O6  238.141638
# 48                                 C10H22O6  238.141638
# 49                                 C10H22O6  238.141638
# ...                                     ...         ...
# 56292                              C18H32O2  280.240230
# 57074                               C12H16O  176.120115
# 57076                              C15H24O2  236.177630
# 57177                                C15H24  204.187801
# 57397                               C15H20O  216.151415
#
#             score_cfm_db_spec2vec  delta_cfm_spec2vec
# Feature_id
# 38                       0.579498          288.289962
# 40                       0.553819          332.316262
# 45                       0.594717          302.305562
# 48                       0.563774          288.289962
# 49                       0.516715          376.342562
# ...                           ...                 ...
# 56292                    0.588280          299.259270
# 57074                    0.515460          228.143885
# 57076                    0.536186          184.081670
# 57177                    0.516802          209.190099
# 57397                    0.575496          188.112885
#
# [2175 rows x 7 columns]

# %%
df_cfm_spec2vec=df_cfm_spec2vec.drop(["m/z","hit1_m/z"], axis=1)
df_cfm_spec2vec
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#            cfm_db_spec2vec_hit          smiles_cfm_db_spec2vec  \
# Feature_id
# 38                       62551              C(COCCOCCOCCOCCO)O
# 40                       62551              C(COCCOCCOCCOCCO)O
# 45                       62551              C(COCCOCCOCCOCCO)O
# 48                       62551              C(COCCOCCOCCOCCO)O
# 49                       62551              C(COCCOCCOCCOCCO)O
# ...                        ...                             ...
# 56292                  5312697        CCCC#CCCCCCCCCCCCCC(=O)O
# 57074               PMA_119625      CC1=C2CCCC[C@@]2(C)C=CC1=O
# 57076               PMA_054517  CC1=CCC(CC1=O)C(=C)CCCC(C)(C)O
# 57177               CNP0287127      C=C1C2CCC32CC(CCC13C)C(C)C
# 57397               PMA_210145     Cc1coc2CC3(C)CCCC(=C)C3Cc12
#
#            MolecularFormula_cfm_db_spec2vec  score_cfm_db_spec2vec  \
# Feature_id
# 38                                 C10H22O6               0.579498
# 40                                 C10H22O6               0.553819
# 45                                 C10H22O6               0.594717
# 48                                 C10H22O6               0.563774
# 49                                 C10H22O6               0.516715
# ...                                     ...                    ...
# 56292                              C18H32O2               0.588280
# 57074                               C12H16O               0.515460
# 57076                              C15H24O2               0.536186
# 57177                                C15H24               0.516802
# 57397                               C15H20O               0.575496
#
#             delta_cfm_spec2vec
# Feature_id
# 38                  288.289962
# 40                  332.316262
# 45                  302.305562
# 48                  288.289962
# 49                  376.342562
# ...                        ...
# 56292               299.259270
# 57074               228.143885
# 57076               184.081670
# 57177               209.190099
# 57397               188.112885
#
# [2175 rows x 5 columns]

# %% [markdown]
# Get CFM big DB search by modified cosine score, keep only ic score above 0.5 and more than 5 peaks

# %%
df_cfm_cosine

df_cfm_cosine=df_cfm_cosine.rename(columns={"cosine": "cosine_cfm_db_cosine",'Smiles 1':"smiles_cfm_db_cosine","Library Hit 1":"Library_Hit_cfm_db_cosine","numoffpeaks 1" :"numoffpeaks_cfm_db_cosine"})

df_cfm_cosine = df_cfm_cosine[(df_cfm_cosine.cosine_cfm_db_cosine > 0.5) & (df_cfm_cosine.numoffpeaks_cfm_db_cosine > 5)]




df_cfm_cosine["smiles_cfm_db_cosine"]=df_cfm_cosine["smiles_cfm_db_cosine"].apply(lambda x: convert(x))





df_cfm_cosine["MF_cfm_db_cosine"]=df_cfm_cosine["smiles_cfm_db_cosine"].apply(lambda x: smilestomf(x))

    
#df_cfm_cosine= df_cfm_cosine.assign(MF_cfm_db_cosine=MF)
#df_cfm_j=df_cfm_j.rename(columns={"MF_j_cfm": "Compound_Name"})
df_cfm_cosine= df_cfm_cosine.assign(delta_mz_cfm_db_cosine=df_cfm_cosine["m/z"]-df_cfm_cosine["m/z 1"])
df_cfm_cosine=df_cfm_cosine.drop(["m/z","m/z 1"], axis=1)
df_cfm_cosine
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#             cosine_cfm_db_cosine Library_Hit_cfm_db_cosine  \
# Feature_id
# 3                       0.667835                CNP0179408
# 5                       0.674954                PMA_080810
# 6                       0.560974          ZINC000245174543
# 10                      0.697262                PMA_037304
# 20                      0.536068          ZINC000253499747
# ...                          ...                       ...
# 57547                   0.594086          ZINC000036369833
# 57597                   0.597434                PMA_134177
# 57602                   0.583535                PMA_134177
# 57606                   0.583535                PMA_134177
# 57607                   0.583535                PMA_134177
#
#             numoffpeaks_cfm_db_cosine  \
# Feature_id
# 3                                   7
# 5                                   7
# 6                                  14
# 10                                  6
# 20                                 13
# ...                               ...
# 57547                               6
# 57597                               8
# 57602                               7
# 57606                               7
# 57607                               7
#
#                                          smiles_cfm_db_cosine  \
# Feature_id
# 3                        CC(C)CCCCCCCCC(=O)N1CCCC1C1=CN=CC=C1
# 5                    CC(C)CCCCCCCCC(=O)N1CCC[C@H]1C1=CN=CC=C1
# 6           C[C@]12CCCC[C@@H]1CC[C@H]1[C@H]2CC[C@@]2(C)[C@...
# 10              CC[C@H](C)CCCCCCCCC(=O)N1CCC[C@H]1C1=CN=CC=C1
# 20          C[C@]12CCCC[C@H]1CC[C@H]1[C@H]2CC[C@]2(C)[C@@H...
# ...                                                       ...
# 57547       COC1=C(OC)C(OC)=CC(/C=C/C(=O)N(CC2=CC3=C(C=CN3...
# 57597                                CNCCC1=CN(C)C2=CC=CC=C12
# 57602                                CNCCC1=CN(C)C2=CC=CC=C12
# 57606                                CNCCC1=CN(C)C2=CC=CC=C12
# 57607                                CNCCC1=CN(C)C2=CC=CC=C12
#
#            MF_cfm_db_cosine  delta_mz_cfm_db_cosine
# Feature_id
# 3                 C21H34N2O                1.007686
# 5                 C21H34N2O                1.007686
# 6                   C20H34O               48.081134
# 10                C22H36N2O                1.007736
# 20                  C20H34O               48.081034
# ...                     ...                     ...
# 57547            C24H26N2O4             -243.066357
# 57597              C12H16N2              -25.008548
# 57602              C12H16N2              -25.008548
# 57606              C12H16N2              -25.008449
# 57607              C12H16N2              -25.008548
#
# [3390 rows x 6 columns]

# %% [markdown]
# Do first merges first prio to Emmanuel Database Hits

# %%
df_em.loc[:,'Level'] = 'N'
netw_quant = df_quant.join(df_em, how="outer")
#result = netw_quant.join(df_motif, how="outer")
result= netw_quant.join(df_sirius, how="outer")
result= result.join(df_cfm_cosine, how="outer")
result= result.join(df_cfm_spec2vec, how="outer")
result= result.join(df_cfm_j, how="outer")
result= result.join(df_moldis_j, how="outer")
result= result.join(df_moldis, how="outer")
result= result.join(df_cmpid, how="outer")
result= result.join(df_cano, how="outer")

result
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#           row m/z  row retention time       07 Nrep       07 Nnes  \
# 1      375.300874           26.591875  0.000000e+00  0.000000e+00
# 2      375.300905           26.708085  1.399826e+08  7.982489e+07
# 3      331.274781           27.032871  1.456369e+08  1.578602e+08
# 4      375.300859           27.204353  1.853471e+08  1.131553e+08
# 5      331.274799           27.624355  1.225282e+08  4.539143e+07
# ...           ...                 ...           ...           ...
# 57596  163.122893           24.635752  3.057750e+03  0.000000e+00
# 57597  163.122798           22.623363  5.059680e+03  7.624705e+03
# 57602  163.122847           26.424650  0.000000e+00  0.000000e+00
# 57606  163.122859           26.160844  5.060950e+03  0.000000e+00
# 57607  163.122787           26.670803  0.000000e+00  0.000000e+00
#
#            07 Nrxs       07 Nsto     07 Ntab  08 Nglu    10 Nben     10 Ncle  \
# 1            0.000  0.000000e+00      0.0000    0.000     0.0000      0.0000
# 2            0.000  1.135378e+08  60783.3560    0.000     0.0000   2594.5600
# 3      5095030.375  1.636117e+06  12148.4585  390.456     0.0000    401.3875
# 4      8789294.723  2.054237e+08   7070.3310    0.000     0.0000   2070.4005
# 5      3250219.092  2.809773e+06   4730.8535  217.019   148.2960      0.0000
# ...            ...           ...         ...      ...        ...         ...
# 57596        0.000  0.000000e+00      0.0000    0.000  1517.4250   5592.0165
# 57597      358.600  2.810580e+03   3549.6620    0.000  6276.6915  12382.8120
# 57602      176.704  0.000000e+00      0.0000    0.000  1222.3840   5906.0730
# 57606      204.249  3.038480e+03      0.0000    0.000  1921.6025   9111.0390
# 57607        0.000  0.000000e+00   6044.3250    0.000  3081.0605   6425.2840
#
#        ...                                 smiles_moldis  ConfidenceScore  \
# 1      ...  CCCCCCCCCCC[C@H](O)CC(=O)N1CCC[C@H]1c1cccnc1              NaN
# 2      ...                                           NaN              NaN
# 3      ...                                           NaN              NaN
# 4      ...                                           NaN              NaN
# 5      ...                                           NaN              NaN
# ...    ...                                           ...              ...
# 57596  ...                                           NaN         0.703361
# 57597  ...                                           NaN         0.712005
# 57602  ...                                           NaN         0.728219
# 57606  ...                                           NaN              NaN
# 57607  ...                                           NaN              NaN
#
#        name-sir           smiles-sir   cano_most_specific_class  \
# 1           NaN                  NaN   Heteroaromatic compounds
# 2           NaN                  NaN                 Benzenoids
# 3           NaN                  NaN        Azacyclic compounds
# 4           NaN                  NaN  Pyridines and derivatives
# 5           NaN                  NaN        Azacyclic compounds
# ...         ...                  ...                        ...
# 57596  Habitrol  CN1CCCC1C2=CN=CC=C2              Aralkylamines
# 57597  Habitrol  CN1CCCC1C2=CN=CC=C2              Aralkylamines
# 57602  Habitrol  CN1CCCC1C2=CN=CC=C2              Aralkylamines
# 57606       NaN                  NaN              Aralkylamines
# 57607       NaN                  NaN              Aralkylamines
#
#         cano_level_5  cano_subclass                 cano_class  \
# 1                NaN            NaN   Heteroaromatic compounds
# 2                NaN            NaN                        NaN
# 3                NaN            NaN        Azacyclic compounds
# 4                NaN            NaN  Pyridines and derivatives
# 5                NaN            NaN        Azacyclic compounds
# ...              ...            ...                        ...
# 57596  Aralkylamines         Amines   Organonitrogen compounds
# 57597  Aralkylamines         Amines   Organonitrogen compounds
# 57602  Aralkylamines         Amines   Organonitrogen compounds
# 57606  Aralkylamines         Amines   Organonitrogen compounds
# 57607  Aralkylamines         Amines   Organonitrogen compounds
#
#                     cano_superclass  \
# 1      Organoheterocyclic compounds
# 2                        Benzenoids
# 3      Organoheterocyclic compounds
# 4      Organoheterocyclic compounds
# 5      Organoheterocyclic compounds
# ...                             ...
# 57596    Organic nitrogen compounds
# 57597    Organic nitrogen compounds
# 57602    Organic nitrogen compounds
# 57606    Organic nitrogen compounds
# 57607    Organic nitrogen compounds
#
#                                 cano_all_classifications
# 1      Organic compounds; Organoheterocyclic compound...
# 2      Organic compounds; Organoheterocyclic compound...
# 3      Organic compounds; Organoheterocyclic compound...
# 4      Organic compounds; Organoheterocyclic compound...
# 5      Organic compounds; Alcohols and polyols; Organ...
# ...                                                  ...
# 57596  Organic compounds; Organoheterocyclic compound...
# 57597  Organic compounds; Organoheterocyclic compound...
# 57602  Organic compounds; Organoheterocyclic compound...
# 57606  Organic compounds; Organoheterocyclic compound...
# 57607  Organic compounds; Organoheterocyclic compound...
#
# [17901 rows x 158 columns]

# %% [markdown]
# add gnps second prio

# %%
df_network['Level'] = np.where(pd.isnull(df_network['Compound_Name'])!= True, "GNPS",None)



#clean=result.drop(["Precursor Mass","Retention Time","Document Annotation","Document"], axis=1)
clean= result

cmpd_name= clean.Compound_Name.fillna(df_network.Compound_Name).to_frame() #Compound_Name', 'MassDiff', 'Smiles
level=clean.Level.fillna(df_network.Level).to_frame()
smiles= clean.Smiles.fillna(df_network.Smiles).to_frame()
clean=clean.drop(["Compound_Name","Smiles","Level"], axis=1)


clean=pd.concat([clean, cmpd_name,smiles,level ], axis=1)
df_network_red=df_network.drop(["Compound_Name","Smiles","Level"], axis=1)
clean = clean.join(df_network_red, how="outer")
clean.head()
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#       row m/z  row retention time      07 Nrep       07 Nnes      07 Nrxs  \
# 1  375.300874           26.591875          0.0  0.000000e+00        0.000
# 2  375.300905           26.708085  139982614.0  7.982489e+07        0.000
# 3  331.274781           27.032871  145636857.5  1.578602e+08  5095030.375
# 4  375.300859           27.204353  185347092.7  1.131553e+08  8789294.723
# 5  331.274799           27.624355  122528191.3  4.539143e+07  3250219.092
#
#         07 Nsto     07 Ntab  08 Nglu  10 Nben    10 Ncle  ...  Ion_Source  \
# 1  0.000000e+00      0.0000    0.000    0.000     0.0000  ...      LC-ESI
# 2  1.135378e+08  60783.3560    0.000    0.000  2594.5600  ...      LC-ESI
# 3  1.636117e+06  12148.4585  390.456    0.000   401.3875  ...      LC-ESI
# 4  2.054237e+08   7070.3310    0.000    0.000  2070.4005  ...      LC-ESI
# 5  2.809773e+06   4730.8535  217.019  148.296     0.0000  ...      LC-ESI
#
#     IonMode  Library_Class  MassDiff   MQScore  MZErrorPPM  number of spectra  \
# 1  Positive            3.0  0.000092  0.764151    0.243945                 34
# 2  Positive            3.0  0.000092  0.763730    0.243945                 43
# 3  Positive            3.0  0.000183  0.949112    0.552730                 37
# 4  Positive            3.0  0.000092  0.762207    0.243945                 50
# 5  Positive            3.0  0.000183  0.953081    0.552730                 38
#
#                   PI          SpectrumID  sum(precursor intensity)
# 1  Emmanuel Gaquerel  CCMSLIB00005788032                65100000.0
# 2  Emmanuel Gaquerel  CCMSLIB00005788032                79200000.0
# 3           Gaquerel  CCMSLIB00005788033               150000000.0
# 4  Emmanuel Gaquerel  CCMSLIB00005788032               117000000.0
# 5           Gaquerel  CCMSLIB00005788033                50100000.0
#
# [5 rows x 195 columns]

# %%
canopus_freq=clean.groupby('componentindex')['cano_subclass'].apply(lambda x: x.mode()).reset_index(level=1, drop=True).reset_index()
canopus_freq=canopus_freq.drop_duplicates(subset=['componentindex'], keep='first')
canopus_freq
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       componentindex                              cano_subclass
# 0                 -1       Amino acids, peptides, and analogues
# 1                  1                                     Ethers
# 2                  2                Carboxylic acid derivatives
# 3                  4  Carbohydrates and carbohydrate conjugates
# 4                  6                               Thiadiazoles
# ...              ...                                        ...
# 1602            3880                       Alcohols and polyols
# 1603            3902                              Triterpenoids
# 1604            3987                               Diterpenoids
# 1606            3995                       Alcohols and polyols
# 1607            3999                         Glycosphingolipids
#
# [1315 rows x 2 columns]

# %%
canopus_freq=canopus_freq.set_index("componentindex")
canopus_freq=canopus_freq.rename(columns={"cano_subclass" : "canopus_enhancer_subclass"})
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):

# %%
canopus_freq1=clean.groupby('componentindex')['cano_superclass'].apply(lambda x: x.mode()).reset_index(level=1, drop=True).reset_index()
canopus_freq1=canopus_freq1.drop_duplicates(subset=['componentindex'], keep='first')
canopus_freq1
# Out:
#       componentindex                  cano_superclass
# 0                 -1  Lipids and lipid-like molecules
# 1                  1         Organic oxygen compounds
# 2                  2  Lipids and lipid-like molecules
# 4                  4                       Benzenoids
# 6                  6     Organoheterocyclic compounds
# ...              ...                              ...
# 1647            3902  Lipids and lipid-like molecules
# 1648            3987  Lipids and lipid-like molecules
# 1649            3995         Organic oxygen compounds
# 1651            3999  Lipids and lipid-like molecules
# 1652            4011  Lipids and lipid-like molecules
#
# [1430 rows x 2 columns]

# %%
canopus_freq1=canopus_freq1.set_index("componentindex")
canopus_freq1=canopus_freq1.rename(columns={"cano_superclass" : "canopus_enhancer_superclass"})
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):

# %%
canopus_freq2=clean.groupby('componentindex')['cano_most_specific_class'].apply(lambda x: x.mode()).reset_index(level=1, drop=True).reset_index()
canopus_freq2=canopus_freq2.drop_duplicates(subset=['componentindex'], keep='first')
canopus_freq2
# Out:
#       componentindex         cano_most_specific_class
# 0                 -1                     Diterpenoids
# 1                  1             Polyethylene glycols
# 2                  2  Lipids and lipid-like molecules
# 4                  4                       Benzenoids
# 8                  6                     Thiadiazoles
# ...              ...                              ...
# 2066            3902                    Triterpenoids
# 2067            3987             Diterpene glycosides
# 2069            3995                     Macrolactams
# 2071            3999               Glycosphingolipids
# 2073            4011                    Prenol lipids
#
# [1430 rows x 2 columns]

# %%
canopus_freq2=canopus_freq2.set_index("componentindex")
canopus_freq2=canopus_freq2.rename(columns={"cano_most_specific_class" : "canopus_enhancer_cano_most_specific_class"})
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):

# %%
clean=clean.reset_index()
clean=clean.set_index("componentindex")

final= clean.join(canopus_freq, how="left")
final= final.join(canopus_freq1, how="left")
final= final.join(canopus_freq2, how="left")
final
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                 index     row m/z  row retention time       07 Nrep  \
# componentindex
# -1                 13  149.023222           21.229848  1.359427e+08
# -1                 30  155.974172            0.178462  1.412411e+07
# -1                 49  614.484237           37.134686  1.386053e+07
# -1                 53  540.447250           38.339231  8.149429e+06
# -1                 54  584.473543           38.358006  1.393637e+07
# ...               ...         ...                 ...           ...
#  3999           37351  621.473344           43.192733  1.705200e+03
#  4011            5695  340.285063           24.927804  0.000000e+00
#  4011           55465  340.284967           24.272761  0.000000e+00
#  4030           34501  197.677215           14.732328  0.000000e+00
#  4030           34515  197.677332           14.857393  0.000000e+00
#
#                      07 Nnes       07 Nrxs       07 Nsto       07 Ntab  \
# componentindex
# -1              1.382029e+08  1.374533e+07  9.175219e+07  1.229461e+07
# -1              1.123981e+07  1.083707e+06  9.555183e+06  1.584404e+06
# -1              2.588403e+07  2.191637e+06  2.755502e+07  1.530908e+06
# -1              8.719363e+06  7.947326e+05  7.730808e+06  8.900204e+05
# -1              1.512933e+07  2.144942e+06  2.135812e+07  8.331676e+05
# ...                      ...           ...           ...           ...
#  3999           1.377360e+03  0.000000e+00  1.506320e+03  0.000000e+00
#  4011           0.000000e+00  0.000000e+00  0.000000e+00  1.326134e+05
#  4011           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#  4030           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#  4030           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                      08 Nglu       10 Nben  ...  MassDiff  MQScore  \
# componentindex                              ...
# -1              0.000000e+00  0.000000e+00  ...       NaN      NaN
# -1              8.962862e+05  1.131018e+06  ...       NaN      NaN
# -1              1.751402e+07  1.737014e+07  ...       NaN      NaN
# -1              7.117477e+06  7.104920e+06  ...       NaN      NaN
# -1              1.825117e+07  1.460736e+07  ...       NaN      NaN
# ...                      ...           ...  ...       ...      ...
#  3999           0.000000e+00  0.000000e+00  ...       NaN      NaN
#  4011           0.000000e+00  0.000000e+00  ...       NaN      NaN
#  4011           0.000000e+00  0.000000e+00  ...       NaN      NaN
#  4030           0.000000e+00  0.000000e+00  ...       NaN      NaN
#  4030           0.000000e+00  0.000000e+00  ...       NaN      NaN
#
#                 MZErrorPPM  number of spectra   PI  SpectrumID  \
# componentindex
# -1                     NaN                 26  NaN         NaN
# -1                     NaN                112  NaN         NaN
# -1                     NaN                112  NaN         NaN
# -1                     NaN                 63  NaN         NaN
# -1                     NaN                112  NaN         NaN
# ...                    ...                ...  ...         ...
#  3999                  NaN                 56  NaN         NaN
#  4011                  NaN                 32  NaN         NaN
#  4011                  NaN                 16  NaN         NaN
#  4030                  NaN                  6  NaN         NaN
#  4030                  NaN                  5  NaN         NaN
#
#                 sum(precursor intensity)  \
# componentindex
# -1                          1.120000e+08
# -1                          8.600000e+07
# -1                          5.210000e+08
# -1                          1.720000e+08
# -1                          3.670000e+08
# ...                                  ...
#  3999                       4.072771e+05
#  4011                       1.575059e+05
#  4011                       2.247056e+05
#  4030                       2.238860e+05
#  4030                       1.240282e+05
#
#                            canopus_enhancer_subclass  \
# componentindex
# -1              Amino acids, peptides, and analogues
# -1              Amino acids, peptides, and analogues
# -1              Amino acids, peptides, and analogues
# -1              Amino acids, peptides, and analogues
# -1              Amino acids, peptides, and analogues
# ...                                              ...
#  3999                             Glycosphingolipids
#  4011                                            NaN
#  4011                                            NaN
#  4030                                            NaN
#  4030                                            NaN
#
#                     canopus_enhancer_superclass  \
# componentindex
# -1              Lipids and lipid-like molecules
# -1              Lipids and lipid-like molecules
# -1              Lipids and lipid-like molecules
# -1              Lipids and lipid-like molecules
# -1              Lipids and lipid-like molecules
# ...                                         ...
#  3999           Lipids and lipid-like molecules
#  4011           Lipids and lipid-like molecules
#  4011           Lipids and lipid-like molecules
#  4030                                       NaN
#  4030                                       NaN
#
#                 canopus_enhancer_cano_most_specific_class
# componentindex
# -1                                           Diterpenoids
# -1                                           Diterpenoids
# -1                                           Diterpenoids
# -1                                           Diterpenoids
# -1                                           Diterpenoids
# ...                                                   ...
#  3999                                  Glycosphingolipids
#  4011                                       Prenol lipids
#  4011                                       Prenol lipids
#  4030                                                 NaN
#  4030                                                 NaN
#
# [17901 rows x 198 columns]

# %%
df_motif
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Document              Motif  Probability  Overlap Score  \
# row ID
# 1              1          motif_433        0.579          0.791
# 1              1          motif_591        0.164          0.183
# 1              1          motif_502        0.111          0.603
# 1              1  gnps_motif_43.m2m        0.102          0.938
# 2              2          motif_433        0.727          0.813
# ...          ...                ...          ...            ...
# 57597      57597          motif_604        0.723          0.735
# 57597      57597          motif_496        0.256          0.275
# 57602      57602          motif_496        0.976          0.892
# 57606      57606          motif_496        0.976          0.892
# 57607      57607          motif_496        0.976          0.892
#
#         Precursor Mass Retention Time Document Annotation
# row ID
# 1             375.3009           None                None
# 1             375.3009           None                None
# 1             375.3009           None                None
# 1             375.3009           None                None
# 2             375.3009           None                None
# ...                ...            ...                 ...
# 57597         163.1228           None                None
# 57597         163.1228           None                None
# 57602         163.1228           None                None
# 57606         163.1229           None                None
# 57607         163.1228           None                None
#
# [63683 rows x 7 columns]

# %%
final=final.reset_index()
final=final.set_index("index")
final=final.join(df_motif, how="outer")
final=final.drop(["Precursor Mass","Retention Time","Document Annotation","Document"], axis=1)
final=final.reset_index()
final=final.set_index("Motif")
final
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                    index  componentindex     row m/z  row retention time  \
# Motif
# motif_433              1            1298  375.300874           26.591875
# motif_591              1            1298  375.300874           26.591875
# motif_502              1            1298  375.300874           26.591875
# gnps_motif_43.m2m      1            1298  375.300874           26.591875
# motif_433              2            1298  375.300905           26.708085
# ...                  ...             ...         ...                 ...
# motif_604          57597            1132  163.122798           22.623363
# motif_496          57597            1132  163.122798           22.623363
# motif_496          57602            1161  163.122847           26.424650
# motif_496          57606            1161  163.122859           26.160844
# motif_496          57607            1161  163.122787           26.670803
#
#                         07 Nrep       07 Nnes  07 Nrxs       07 Nsto  \
# Motif
# motif_433          0.000000e+00  0.000000e+00    0.000  0.000000e+00
# motif_591          0.000000e+00  0.000000e+00    0.000  0.000000e+00
# motif_502          0.000000e+00  0.000000e+00    0.000  0.000000e+00
# gnps_motif_43.m2m  0.000000e+00  0.000000e+00    0.000  0.000000e+00
# motif_433          1.399826e+08  7.982489e+07    0.000  1.135378e+08
# ...                         ...           ...      ...           ...
# motif_604          5.059680e+03  7.624705e+03  358.600  2.810580e+03
# motif_496          5.059680e+03  7.624705e+03  358.600  2.810580e+03
# motif_496          0.000000e+00  0.000000e+00  176.704  0.000000e+00
# motif_496          5.060950e+03  0.000000e+00  204.249  3.038480e+03
# motif_496          0.000000e+00  0.000000e+00    0.000  0.000000e+00
#
#                      07 Ntab  08 Nglu  ...  MZErrorPPM  number of spectra  \
# Motif                                  ...
# motif_433              0.000      0.0  ...    0.243945                 34
# motif_591              0.000      0.0  ...    0.243945                 34
# motif_502              0.000      0.0  ...    0.243945                 34
# gnps_motif_43.m2m      0.000      0.0  ...    0.243945                 34
# motif_433          60783.356      0.0  ...    0.243945                 43
# ...                      ...      ...  ...         ...                ...
# motif_604           3549.662      0.0  ...         NaN                103
# motif_496           3549.662      0.0  ...         NaN                103
# motif_496              0.000      0.0  ...         NaN                 97
# motif_496              0.000      0.0  ...         NaN                 96
# motif_496           6044.325      0.0  ...         NaN                 95
#
#                                   PI          SpectrumID  \
# Motif
# motif_433          Emmanuel Gaquerel  CCMSLIB00005788032
# motif_591          Emmanuel Gaquerel  CCMSLIB00005788032
# motif_502          Emmanuel Gaquerel  CCMSLIB00005788032
# gnps_motif_43.m2m  Emmanuel Gaquerel  CCMSLIB00005788032
# motif_433          Emmanuel Gaquerel  CCMSLIB00005788032
# ...                              ...                 ...
# motif_604                        NaN                 NaN
# motif_496                        NaN                 NaN
# motif_496                        NaN                 NaN
# motif_496                        NaN                 NaN
# motif_496                        NaN                 NaN
#
#                    sum(precursor intensity)  canopus_enhancer_subclass  \
# Motif
# motif_433                        65100000.0                        NaN
# motif_591                        65100000.0                        NaN
# motif_502                        65100000.0                        NaN
# gnps_motif_43.m2m                65100000.0                        NaN
# motif_433                        79200000.0                        NaN
# ...                                     ...                        ...
# motif_604                        53000000.0                     Amines
# motif_496                        53000000.0                     Amines
# motif_496                        51900000.0                     Amines
# motif_496                        52800000.0                     Amines
# motif_496                        44600000.0                     Amines
#
#                     canopus_enhancer_superclass  \
# Motif
# motif_433          Organoheterocyclic compounds
# motif_591          Organoheterocyclic compounds
# motif_502          Organoheterocyclic compounds
# gnps_motif_43.m2m  Organoheterocyclic compounds
# motif_433          Organoheterocyclic compounds
# ...                                         ...
# motif_604            Organic nitrogen compounds
# motif_496            Organic nitrogen compounds
# motif_496            Organic nitrogen compounds
# motif_496            Organic nitrogen compounds
# motif_496            Organic nitrogen compounds
#
#                    canopus_enhancer_cano_most_specific_class  Probability  \
# Motif
# motif_433                          Pyridines and derivatives        0.579
# motif_591                          Pyridines and derivatives        0.164
# motif_502                          Pyridines and derivatives        0.111
# gnps_motif_43.m2m                  Pyridines and derivatives        0.102
# motif_433                          Pyridines and derivatives        0.727
# ...                                                      ...          ...
# motif_604                                      Aralkylamines        0.723
# motif_496                                      Aralkylamines        0.256
# motif_496                                      Aralkylamines        0.976
# motif_496                                      Aralkylamines        0.976
# motif_496                                      Aralkylamines        0.976
#
#                    Overlap Score
# Motif
# motif_433                  0.791
# motif_591                  0.183
# motif_502                  0.603
# gnps_motif_43.m2m          0.938
# motif_433                  0.813
# ...                          ...
# motif_604                  0.735
# motif_496                  0.275
# motif_496                  0.892
# motif_496                  0.892
# motif_496                  0.892
#
# [63683 rows x 201 columns]

# %%
df_frag=df_frag.rename(columns={"Probability": "Motif-Probability"})
final = final.join(df_frag, how="outer")
df_anno=df_anno.rename(columns={"Degree": "Motif-count"})
final = final.join(df_anno, how="inner")
final=final.rename(columns={"index": "Feature_ID"})
final
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                           Feature_ID  componentindex     row m/z  \
# StrepSalini_motif_10.m2m     38013.0            -1.0  217.072334
# StrepSalini_motif_10.m2m     38013.0            -1.0  217.072334
# StrepSalini_motif_10.m2m     45744.0            49.0  725.349513
# StrepSalini_motif_10.m2m     45744.0            49.0  725.349513
# StrepSalini_motif_10.m2m     51645.0           121.0  456.249684
# ...                              ...             ...         ...
# urine_mass2motif_97.m2m      50614.0           229.0  483.149700
# urine_mass2motif_97.m2m      50632.0            -1.0  394.197885
# urine_mass2motif_97.m2m      50632.0            -1.0  394.197885
# urine_mass2motif_97.m2m      50632.0            -1.0  394.197885
# urine_mass2motif_97.m2m      50632.0            -1.0  394.197885
#
#                           row retention time  07 Nrep  07 Nnes  07 Nrxs  \
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            6.908989      0.0      0.0      0.0
# ...                                      ...      ...      ...      ...
# urine_mass2motif_97.m2m            12.136402      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
#
#                           07 Nsto  07 Ntab  08 Nglu  ...  \
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000  208.278  ...
# ...                           ...      ...      ...  ...
# urine_mass2motif_97.m2m       0.0    0.000    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
#
#                                canopus_enhancer_superclass  \
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m  Phenylpropanoids and polyketides
# ...                                                    ...
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
#
#                           canopus_enhancer_cano_most_specific_class  \
# StrepSalini_motif_10.m2m                               Diterpenoids
# StrepSalini_motif_10.m2m                               Diterpenoids
# StrepSalini_motif_10.m2m                           Alkyl glycosides
# StrepSalini_motif_10.m2m                           Alkyl glycosides
# StrepSalini_motif_10.m2m                Amino acids and derivatives
# ...                                                             ...
# urine_mass2motif_97.m2m                              Saccharolipids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
#
#                           Probability  Overlap Score            Feature  \
# StrepSalini_motif_10.m2m        0.138          0.012  fragment_300.1525
# StrepSalini_motif_10.m2m        0.138          0.012  fragment_456.2525
# StrepSalini_motif_10.m2m        0.082          0.015  fragment_300.1525
# StrepSalini_motif_10.m2m        0.082          0.015  fragment_456.2525
# StrepSalini_motif_10.m2m        0.080          0.124  fragment_300.1525
# ...                               ...            ...                ...
# urine_mass2motif_97.m2m         0.050          0.072   fragment_92.0575
# urine_mass2motif_97.m2m         0.132          0.402  fragment_110.0625
# urine_mass2motif_97.m2m         0.132          0.402  fragment_152.0675
# urine_mass2motif_97.m2m         0.132          0.402   fragment_65.0375
# urine_mass2motif_97.m2m         0.132          0.402   fragment_92.0575
#
#                           Min m/z  Max m/z  Motif-Probability  Motif-count  \
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# ...                           ...      ...                ...          ...
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
# urine_mass2motif_97.m2m   110.060  110.065              0.409            4
# urine_mass2motif_97.m2m   152.065  152.070              0.280            4
# urine_mass2motif_97.m2m    65.035   65.040              0.053            4
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
#
#                                                                  Annotation
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# ...                                                                     ...
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
#
# [214354 rows x 207 columns]

# %%
final_df = final[final["Feature_ID"].notna()]
final_df["Feature_ID"]=final_df["Feature_ID"].astype("int")
final_df
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-26-9fb853af852d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Feature_ID"]=final_df["Feature_ID"].astype("int")
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                           Feature_ID  componentindex     row m/z  \
# StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# StrepSalini_motif_10.m2m       45744            49.0  725.349513
# StrepSalini_motif_10.m2m       45744            49.0  725.349513
# StrepSalini_motif_10.m2m       51645           121.0  456.249684
# ...                              ...             ...         ...
# urine_mass2motif_97.m2m        50614           229.0  483.149700
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
#
#                           row retention time  07 Nrep  07 Nnes  07 Nrxs  \
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            6.908989      0.0      0.0      0.0
# ...                                      ...      ...      ...      ...
# urine_mass2motif_97.m2m            12.136402      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
#
#                           07 Nsto  07 Ntab  08 Nglu  ...  \
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...
# StrepSalini_motif_10.m2m      0.0    0.000  208.278  ...
# ...                           ...      ...      ...  ...
# urine_mass2motif_97.m2m       0.0    0.000    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...
#
#                                canopus_enhancer_superclass  \
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m   Lipids and lipid-like molecules
# StrepSalini_motif_10.m2m  Phenylpropanoids and polyketides
# ...                                                    ...
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
# urine_mass2motif_97.m2m    Lipids and lipid-like molecules
#
#                           canopus_enhancer_cano_most_specific_class  \
# StrepSalini_motif_10.m2m                               Diterpenoids
# StrepSalini_motif_10.m2m                               Diterpenoids
# StrepSalini_motif_10.m2m                           Alkyl glycosides
# StrepSalini_motif_10.m2m                           Alkyl glycosides
# StrepSalini_motif_10.m2m                Amino acids and derivatives
# ...                                                             ...
# urine_mass2motif_97.m2m                              Saccharolipids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
# urine_mass2motif_97.m2m                                Diterpenoids
#
#                           Probability  Overlap Score            Feature  \
# StrepSalini_motif_10.m2m        0.138          0.012  fragment_300.1525
# StrepSalini_motif_10.m2m        0.138          0.012  fragment_456.2525
# StrepSalini_motif_10.m2m        0.082          0.015  fragment_300.1525
# StrepSalini_motif_10.m2m        0.082          0.015  fragment_456.2525
# StrepSalini_motif_10.m2m        0.080          0.124  fragment_300.1525
# ...                               ...            ...                ...
# urine_mass2motif_97.m2m         0.050          0.072   fragment_92.0575
# urine_mass2motif_97.m2m         0.132          0.402  fragment_110.0625
# urine_mass2motif_97.m2m         0.132          0.402  fragment_152.0675
# urine_mass2motif_97.m2m         0.132          0.402   fragment_65.0375
# urine_mass2motif_97.m2m         0.132          0.402   fragment_92.0575
#
#                           Min m/z  Max m/z  Motif-Probability  Motif-count  \
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# ...                           ...      ...                ...          ...
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
# urine_mass2motif_97.m2m   110.060  110.065              0.409            4
# urine_mass2motif_97.m2m   152.065  152.070              0.280            4
# urine_mass2motif_97.m2m    65.035   65.040              0.053            4
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
#
#                                                                  Annotation
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# ...                                                                     ...
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
#
# [214264 rows x 207 columns]

# %% [markdown]
# check if there is no "real" database annotation

# %%
in_silico_ms2lda=final_df.reset_index()
in_silico_ms2lda=in_silico_ms2lda.rename(columns={"index": "Motif"})
in_silico_ms2lda = in_silico_ms2lda.groupby("Motif").filter(lambda x : (x['Compound_Name'].isna()==True).all())

in_silico_ms2lda=in_silico_ms2lda.groupby("Motif").filter(lambda x : x.shape[0]>2)
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
in_silico_ms2lda.groupby("Motif").size()
# Out:
# Motif
# StrepSalini_motif_10.m2m     10
# StrepSalini_motif_105.m2m     3
# StrepSalini_motif_106.m2m    12
# StrepSalini_motif_108.m2m    40
# StrepSalini_motif_110.m2m    78
#                              ..
# urine_mass2motif_83.m2m      51
# urine_mass2motif_90.m2m      70
# urine_mass2motif_94.m2m      55
# urine_mass2motif_95.m2m      66
# urine_mass2motif_97.m2m      16
# Length: 376, dtype: int64

# %% [markdown]
# create empty columns for consensus structures

# %%
in_silico_ms2lda["motif_mls0"]=np.nan
in_silico_ms2lda["motif_mls1"]=np.nan
in_silico_ms2lda["motif_mls2"]=np.nan
in_silico_ms2lda["motif_mls3"]=np.nan
in_silico_ms2lda
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                            Motif  Feature_ID  componentindex     row m/z  \
# 0       StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# 1       StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# 2       StrepSalini_motif_10.m2m       45744            49.0  725.349513
# 3       StrepSalini_motif_10.m2m       45744            49.0  725.349513
# 4       StrepSalini_motif_10.m2m       51645           121.0  456.249684
# ...                          ...         ...             ...         ...
# 214259   urine_mass2motif_97.m2m       50614           229.0  483.149700
# 214260   urine_mass2motif_97.m2m       50632            -1.0  394.197885
# 214261   urine_mass2motif_97.m2m       50632            -1.0  394.197885
# 214262   urine_mass2motif_97.m2m       50632            -1.0  394.197885
# 214263   urine_mass2motif_97.m2m       50632            -1.0  394.197885
#
#         row retention time  07 Nrep  07 Nnes  07 Nrxs  07 Nsto  07 Ntab  ...  \
# 0                 1.447478      0.0      0.0      0.0      0.0    0.000  ...
# 1                 1.447478      0.0      0.0      0.0      0.0    0.000  ...
# 2                16.725416      0.0      0.0      0.0      0.0    0.000  ...
# 3                16.725416      0.0      0.0      0.0      0.0    0.000  ...
# 4                 6.908989      0.0      0.0      0.0      0.0    0.000  ...
# ...                    ...      ...      ...      ...      ...      ...  ...
# 214259           12.136402      0.0      0.0      0.0      0.0    0.000  ...
# 214260            2.813640      0.0      0.0      0.0      0.0   90.675  ...
# 214261            2.813640      0.0      0.0      0.0      0.0   90.675  ...
# 214262            2.813640      0.0      0.0      0.0      0.0   90.675  ...
# 214263            2.813640      0.0      0.0      0.0      0.0   90.675  ...
#
#                   Feature  Min m/z  Max m/z  Motif-Probability  Motif-count  \
# 0       fragment_300.1525  300.150  300.155              0.234            5
# 1       fragment_456.2525  456.250  456.255              0.105            5
# 2       fragment_300.1525  300.150  300.155              0.234            5
# 3       fragment_456.2525  456.250  456.255              0.105            5
# 4       fragment_300.1525  300.150  300.155              0.234            5
# ...                   ...      ...      ...                ...          ...
# 214259   fragment_92.0575   92.055   92.060              0.072            4
# 214260  fragment_110.0625  110.060  110.065              0.409            4
# 214261  fragment_152.0675  152.065  152.070              0.280            4
# 214262   fragment_65.0375   65.035   65.040              0.053            4
# 214263   fragment_92.0575   92.055   92.060              0.072            4
#
#                                                Annotation  motif_mls0  \
# 0       Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...         NaN
# 1       Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...         NaN
# 2       Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...         NaN
# 3       Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...         NaN
# 4       Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...         NaN
# ...                                                   ...         ...
# 214259                                Paracetamol related         NaN
# 214260                                Paracetamol related         NaN
# 214261                                Paracetamol related         NaN
# 214262                                Paracetamol related         NaN
# 214263                                Paracetamol related         NaN
#
#         motif_mls1  motif_mls2  motif_mls3
# 0              NaN         NaN         NaN
# 1              NaN         NaN         NaN
# 2              NaN         NaN         NaN
# 3              NaN         NaN         NaN
# 4              NaN         NaN         NaN
# ...            ...         ...         ...
# 214259         NaN         NaN         NaN
# 214260         NaN         NaN         NaN
# 214261         NaN         NaN         NaN
# 214262         NaN         NaN         NaN
# 214263         NaN         NaN         NaN
#
# [58091 rows x 211 columns]

# %%
grouped = in_silico_ms2lda.groupby('Motif') # group by motif
dataframes = [group for _, group in grouped]
len(dataframes)
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 376

# %%
here we actually loop through the motifs to calculate the consensus structures

# %%
for i in tqdm(dataframes):
    #print("Motif ",n," from ",len(dataframes))
    mls_results=mls(i,columns)
 
    if len(mls_results)>4:
        mls_results=mls_results[:3]
    else:
        pass
    try:
        for number,smiles in enumerate(mls_results):
            i["motif_mls{}".format(number)]=smiles
    except:
        pass
# Out:
#   0%|          | 0/376 [00:00<?, ?it/s]
# <ipython-input-1-d5cc20beeeb1>:100: DeprecationWarning: The rdkit.Chem.MCS module is deprecated; please use rdkit.Chem.rdFMCS instead.
#   mls.append(Chem.MolToSmiles(MolFromSmarts(MCS.FindMCS(y,timeout=120).smarts)))

# %%
mls_df=pd.concat(dataframes)
mls_df=mls_df.set_index("Feature_ID")
mls_df=mls_df[["Motif","motif_mls0","motif_mls1","motif_mls2","motif_mls3"]]
mls_df.to_csv("mls_motifs.tsv",sep="\t")
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mls_df=pd.concat(dataframes)
mls_df=mls_df.set_index("Motif")
mls_df=mls_df[["motif_mls0","motif_mls1","motif_mls2","motif_mls3"]]
mls_df
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                          motif_mls0 motif_mls1 motif_mls2 motif_mls3
# Motif
# StrepSalini_motif_10.m2m        NaN        NaN        NaN        NaN
# StrepSalini_motif_10.m2m        NaN        NaN        NaN        NaN
# StrepSalini_motif_10.m2m        NaN        NaN        NaN        NaN
# StrepSalini_motif_10.m2m        NaN        NaN        NaN        NaN
# StrepSalini_motif_10.m2m        NaN        NaN        NaN        NaN
# ...                             ...        ...        ...        ...
# urine_mass2motif_97.m2m         NaN        NaN        NaN        NaN
# urine_mass2motif_97.m2m         NaN        NaN        NaN        NaN
# urine_mass2motif_97.m2m         NaN        NaN        NaN        NaN
# urine_mass2motif_97.m2m         NaN        NaN        NaN        NaN
# urine_mass2motif_97.m2m         NaN        NaN        NaN        NaN
#
# [58091 rows x 4 columns]

# %%
#mls_df= pd.read_csv("/Users/delser/Git/phd/mls_motifs.tsv", sep="\t",index_col='Motif') # use to reload consensus substructure table
#mls_df=mls_df.drop(["Feature_ID"], axis=1)
mls_df=mls_df.drop_duplicates()
mls_df
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                                                                   motif_mls0  \
# Motif
# StrepSalini_motif_10.m2m                                                 NaN
# StrepSalini_motif_108.m2m                               C=C(C)C(=O)OC1CCCC1C
# StrepSalini_motif_110.m2m                                          CCCCCCCCC
# StrepSalini_motif_113.m2m                         CCCC(O)C(C)C(OC(C)O)C(C)CO
# StrepSalini_motif_168.m2m                                     CCOC(O)CC(O)CO
# ...                                                                      ...
# urine_mass2motif_80.m2m    CCCC(OC(C)=O)C(C)(CC(O)C(CC)C(C)O)C(COC(C)=O)O...
# urine_mass2motif_83.m2m                                         COCCCOC(C)=O
# urine_mass2motif_90.m2m                      NC(C=O)CC1:C:N:C2:C:C:C:C:C:1:2
# urine_mass2motif_94.m2m                                  CCC1:C:C:C(O):C:C:1
# urine_mass2motif_95.m2m                                      O=C1CC2SCC=CN12
#
#                                                     motif_mls1  \
# Motif
# StrepSalini_motif_10.m2m                                   NaN
# StrepSalini_motif_108.m2m              C=C1CC(C(O)C=O)OC(C)C1C
# StrepSalini_motif_110.m2m                                 CCCC
# StrepSalini_motif_113.m2m                                 CCCC
# StrepSalini_motif_168.m2m           CC(=O)NCCC1:C:C:C(O):C:C:1
# ...                                                        ...
# urine_mass2motif_80.m2m           CC1=CC(=O)NC1=CC1:N:C:C:C:1C
# urine_mass2motif_83.m2m    OCC1OC(OC2:C:C:C:C:C:2O)C(O)C(O)C1O
# urine_mass2motif_90.m2m               CC(NC(=O)CCC(=O)O)C(=O)O
# urine_mass2motif_94.m2m                        OC1:C:C:C:C:C:1
# urine_mass2motif_95.m2m           CCC(N)C(=O)NCCC1:C:C:C:C:C:1
#
#                                          motif_mls2 motif_mls3
# Motif
# StrepSalini_motif_10.m2m                        NaN        NaN
# StrepSalini_motif_108.m2m                  CC(C)CCO        NaN
# StrepSalini_motif_110.m2m             CC(=O)OC(C)CO        NaN
# StrepSalini_motif_113.m2m   CCC(O)C1(CC)CC(C)C(O)O1        NaN
# StrepSalini_motif_168.m2m  NC(CO)CC1:C:C:C(O):C:C:1        NaN
# ...                                             ...        ...
# urine_mass2motif_80.m2m              OCC1OCCC(O)C1O        NaN
# urine_mass2motif_83.m2m                        CCCN        NaN
# urine_mass2motif_90.m2m        O=N(O)C1:C:C:C:C:C:1        NaN
# urine_mass2motif_94.m2m                         NaN        NaN
# urine_mass2motif_95.m2m              C1:C:C:C:C:C:1        NaN
#
# [304 rows x 4 columns]

# %%
final_df=final_df.join(mls_df, how="outer")
final_df
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/pandas/core/indexes/base.py:395: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#                           Feature_ID  componentindex     row m/z  \
# StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# StrepSalini_motif_10.m2m       38013            -1.0  217.072334
# StrepSalini_motif_10.m2m       45744            49.0  725.349513
# StrepSalini_motif_10.m2m       45744            49.0  725.349513
# StrepSalini_motif_10.m2m       51645           121.0  456.249684
# ...                              ...             ...         ...
# urine_mass2motif_97.m2m        50614           229.0  483.149700
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
# urine_mass2motif_97.m2m        50632            -1.0  394.197885
#
#                           row retention time  07 Nrep  07 Nnes  07 Nrxs  \
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            1.447478      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m           16.725416      0.0      0.0      0.0
# StrepSalini_motif_10.m2m            6.908989      0.0      0.0      0.0
# ...                                      ...      ...      ...      ...
# urine_mass2motif_97.m2m            12.136402      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
# urine_mass2motif_97.m2m             2.813640      0.0      0.0      0.0
#
#                           07 Nsto  07 Ntab  08 Nglu  ...            Feature  \
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...  fragment_300.1525
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...  fragment_456.2525
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...  fragment_300.1525
# StrepSalini_motif_10.m2m      0.0    0.000    0.000  ...  fragment_456.2525
# StrepSalini_motif_10.m2m      0.0    0.000  208.278  ...  fragment_300.1525
# ...                           ...      ...      ...  ...                ...
# urine_mass2motif_97.m2m       0.0    0.000    0.000  ...   fragment_92.0575
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...  fragment_110.0625
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...  fragment_152.0675
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...   fragment_65.0375
# urine_mass2motif_97.m2m       0.0   90.675    0.000  ...   fragment_92.0575
#
#                           Min m/z  Max m/z  Motif-Probability  Motif-count  \
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# StrepSalini_motif_10.m2m  456.250  456.255              0.105            5
# StrepSalini_motif_10.m2m  300.150  300.155              0.234            5
# ...                           ...      ...                ...          ...
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
# urine_mass2motif_97.m2m   110.060  110.065              0.409            4
# urine_mass2motif_97.m2m   152.065  152.070              0.280            4
# urine_mass2motif_97.m2m    65.035   65.040              0.053            4
# urine_mass2motif_97.m2m    92.055   92.060              0.072            4
#
#                                                                  Annotation  \
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# StrepSalini_motif_10.m2m  Actinomycin related Mass2Motif (H-VPMeGMeV-OH ...
# ...                                                                     ...
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
# urine_mass2motif_97.m2m                                 Paracetamol related
#
#                           motif_mls0  motif_mls1  motif_mls2  motif_mls3
# StrepSalini_motif_10.m2m         NaN         NaN         NaN         NaN
# StrepSalini_motif_10.m2m         NaN         NaN         NaN         NaN
# StrepSalini_motif_10.m2m         NaN         NaN         NaN         NaN
# StrepSalini_motif_10.m2m         NaN         NaN         NaN         NaN
# StrepSalini_motif_10.m2m         NaN         NaN         NaN         NaN
# ...                              ...         ...         ...         ...
# urine_mass2motif_97.m2m          NaN         NaN         NaN         NaN
# urine_mass2motif_97.m2m          NaN         NaN         NaN         NaN
# urine_mass2motif_97.m2m          NaN         NaN         NaN         NaN
# urine_mass2motif_97.m2m          NaN         NaN         NaN         NaN
# urine_mass2motif_97.m2m          NaN         NaN         NaN         NaN
#
# [214264 rows x 211 columns]

# %%
final_df.to_csv("mls_test_ms2lda.tsv",sep="\t")
# Out:
# /Users/delser/anaconda3/envs/matchms/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
